# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('dataset.csv')

# Filter for Chuck Berry and make an explicit copy
chuck_df = df[df['artists'].str.contains('Chuck Berry', case=False, na=False)].copy()

# Add new column safely
chuck_df['duration_min'] = chuck_df['duration_ms'] / 60000

chuck_df.head()
# Out:
#       Unnamed: 0                track_id      artists  \
# 8163        8163  1S4rxDloMtAduogKeiJZmR  Chuck Berry
# 8164        8164  03MW3H9B2P7tgpvzG3klNI  Chuck Berry
# 8165        8165  52MCmoSCtPRbVN5Njdo6G5  Chuck Berry
# 8166        8166  7m4luTtlene5vS6xUvWxRt  Chuck Berry
# 8168        8168  3RXAcz7Sa6JDZSxcH1EEQ6  Chuck Berry
#
#                                              album_name       track_name  \
# 8163                            CHRISTMAS TOP HITS 2022  Run Rudolph Run
# 8164                     pov: you hear the bells jingle  Run Rudolph Run
# 8165                               Weihnachten Playlist  Run Rudolph Run
# 8166                                Holidays Are Coming  Run Rudolph Run
# 8168  Best Christmas Songs 2022 | For under the Mist...  Run Rudolph Run
#
#       popularity  duration_ms  explicit  danceability  energy  ...  mode  \
# 8163           0       162897     False         0.647   0.876  ...     1
# ...

# %%
# Base scatter plot: compare Energy vs Danceability
scatter = (
    alt.Chart(chuck_df)
    .mark_circle(size=100, opacity=0.7)
    .encode(
        x=alt.X('danceability', title='Danceability'),
        y=alt.Y('energy', title='Energy'),
        color=alt.Color('valence', scale=alt.Scale(scheme='viridis'), title='Valence (Mood)'),
        size=alt.Size('popularity', title='Popularity'),
        tooltip=['track_name', 'album_name', 'popularity', 'duration_min', 'valence', 'tempo']
    )
    .properties(
        title='Chuck Berry Songs: Energy vs Danceability (Colored by Valence)',
        width=600,
        height=400
    )
)
scatter
# Out:
# alt.Chart(...)
