# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('dataset.csv')
elvis_df = df[df['artists'].str.contains('Elvis Presley', case=False, na=False)]
elvis_df['duration_min'] = elvis_df['duration_ms'] / 60000
elvis_df.head()
# Out:
# /var/folders/bt/kfbk8dmx27qf87cbmbdq8qg00000gn/T/ipykernel_53719/3809480346.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elvis_df['duration_min'] = elvis_df['duration_ms'] / 60000
#        Unnamed: 0                track_id        artists  \
# 90000       90000  44AyOl4qVkzS48vBsbNXaC  Elvis Presley
# 90004       90004  452KBpASS5lZLeJWX9Ixub  Elvis Presley
# 90005       90005  1H5IfYyIIAlgDX8zguUzns  Elvis Presley
# 90007       90007  3KJombE6eRPrdrhNJza7T8  Elvis Presley
# 90050       90050  0D1pEisM3QkiacGXJe5dmd  Elvis Presley
#
#                           album_name                      track_name  \
# 90000                    Blue Hawaii      Can't Help Falling in Love
# 90004     Platinum - A Life In Music                  Jailhouse Rock
# 90005          From Elvis in Memphis                Suspicious Minds
# 90007  Santa Claus Is Coming To Town                  Blue Christmas
# 90050               Elvis 30 #1 Hits  (You're The) Devil in Disguise
#
#        popularity  duration_ms  explicit  danceability  energy  ...  mode  \
# 90000          80       182360     False         0.396   0.293  ...     1
# 90004          72       146933     False         0.623   0.537  ...     0
# 90005          76       261279     False         0.487   0.382  ...     1
# 90007           0       128080     False         0.506   0.475  ...     1
# 90050          67       140426     False         0.481   0.733  ...     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 90000       0.0275        0.9410          0.000196    0.1050    0.343
# 90004       0.0726        0.3320          0.000014    0.0963    0.905
# 90005       0.0309        0.0422          0.000005    0.4110    0.714
# 90007       0.0324        0.8300          0.004110    0.1240    0.596
# 90050       0.1650        0.5750          0.000012    0.1080    0.874
#
#          tempo  time_signature  track_genre  duration_min
# 90000  100.307               3  rock-n-roll      3.039333
# 90004  166.885               4  rock-n-roll      2.448883
# 90005  116.557               4  rock-n-roll      4.354650
# 90007   94.494               4  rock-n-roll      2.134667
# 90050  122.909               4  rock-n-roll      2.340433
#
# [5 rows x 22 columns]

# %%
# Base scatter plot: compare Energy vs Danceability
scatter = (
    alt.Chart(elvis_df)
    .mark_circle(size=100, opacity=0.7)
    .encode(
        x=alt.X('danceability', title='Danceability'),
        y=alt.Y('energy', title='Energy'),
        color=alt.Color('valence', scale=alt.Scale(scheme='viridis'), title='Valence (Mood)'),
        size=alt.Size('popularity', title='Popularity'),
        tooltip=['track_name', 'album_name', 'popularity', 'duration_min', 'valence', 'tempo']
    )
    .properties(
        title='Elvis Presley Songs: Energy vs Danceability (Colored by Valence)',
        width=600,
        height=400
    )
)
scatter
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/api.py in ?(self, *args, **kwds)
#    3674         # see https://github.com/ipython/ipython/issues/11038
#    3675         try:
#    3676             dct = self.to_dict(context={"pre_transform": False})
#    3677         except Exception:
# -> 3678             utils.display_traceback(in_ipython=True)
#    3679             return {}
#    3680         else:
#    3681             if renderer := renderers.get():
#
# ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/api.py in ?(self, validate, format, ignore, context)
#    4029             # for easier specification of datum encodings.
#    4030             copy = self.copy(deep=False)
#    4031             copy.data = core.InlineData(values=[{}])
#    4032             return super(Chart, copy).to_dict(**kwds)
# -> 4033         return super().to_dict(**kwds)
#
# ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/api.py in ?(self, validate, format, ignore, context)
#    2000
#    2001         # remaining to_dict calls are not at top level
#    2002         context["top_level"] = False
#    2003
# -> 2004         vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005             validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006         )
#    2007
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(self, validate, ignore, context)
#    1159                 kwds["mark"] = {"type": mark}
#    1160         else:
#    1161             msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162             raise ValueError(msg)
# -> 1163         result = _todict(kwds, context=context, **opts)
#    1164         if validate:
#    1165             # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166             try:
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(obj, context, np_opt, pd_opt)
#     549         return obj.to_dict(validate=False, context=context)
#     550     elif isinstance(obj, (list, tuple)):
#     551         return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552     elif isinstance(obj, dict):
# --> 553         return {
#     554             k: _todict(v, context, np_opt, pd_opt)
#     555             for k, v in obj.items()
#     556             if v is not Undefined
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(.0)
#     553 def _todict(obj: Any, context: dict[str, Any] | None, np_opt: Any, pd_opt: Any) -> Any:  # noqa: C901
# --> 554     """Convert an object to a dict representation."""
#     555     if np_opt is not None:
#     556         np = np_opt
#     557         if isinstance(obj, np.ndarray):
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(obj, context, np_opt, pd_opt)
#     545                 # See https://github.com/vega/altair/issues/1027 for why this is necessary.
#     546                 result += "T00:00:00"
#     547             return result
#     548     if isinstance(obj, SchemaBase):
# --> 549         return obj.to_dict(validate=False, context=context)
#     550     elif isinstance(obj, (list, tuple)):
#     551         return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552     elif isinstance(obj, dict):
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(self, validate, ignore, context)
#    1159                 kwds["mark"] = {"type": mark}
#    1160         else:
#    1161             msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162             raise ValueError(msg)
# -> 1163         result = _todict(kwds, context=context, **opts)
#    1164         if validate:
#    1165             # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166             try:
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(obj, context, np_opt, pd_opt)
#     549         return obj.to_dict(validate=False, context=context)
#     550     elif isinstance(obj, (list, tuple)):
#     551         return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552     elif isinstance(obj, dict):
# --> 553         return {
#     554             k: _todict(v, context, np_opt, pd_opt)
#     555             for k, v in obj.items()
#     556             if v is not Undefined
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(.0)
#     553 def _todict(obj: Any, context: dict[str, Any] | None, np_opt: Any, pd_opt: Any) -> Any:  # noqa: C901
# --> 554     """Convert an object to a dict representation."""
#     555     if np_opt is not None:
#     556         np = np_opt
#     557         if isinstance(obj, np.ndarray):
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(obj, context, np_opt, pd_opt)
#     547             return result
#     548     if isinstance(obj, SchemaBase):
#     549         return obj.to_dict(validate=False, context=context)
#     550     elif isinstance(obj, (list, tuple)):
# --> 551         return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552     elif isinstance(obj, dict):
#     553         return {
#     554             k: _todict(v, context, np_opt, pd_opt)
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(.0)
# --> 551 def _todict(obj: Any, context: dict[str, Any] | None, np_opt: Any, pd_opt: Any) -> Any:  # noqa: C901
#     552     """Convert an object to a dict representation."""
#     553     if np_opt is not None:
#     554         np = np_opt
#
# ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py in ?(obj, context, np_opt, pd_opt)
#     545                 # See https://github.com/vega/altair/issues/1027 for why this is necessary.
#     546                 result += "T00:00:00"
#     547             return result
#     548     if isinstance(obj, SchemaBase):
# --> 549         return obj.to_dict(validate=False, context=context)
#     550     elif isinstance(obj, (list, tuple)):
#     551         return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552     elif isinstance(obj, dict):
#
# ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/schema/channels.py in ?(self, validate, ignore, context)
#     205                         " verify that the field name is not misspelled."
#     206                         " If you are referencing a field from a transform,"
#     207                         " also confirm that the data type is specified correctly."
#     208                     )
# --> 209                     raise ValueError(msg)
#     210                 else:
#     211                     msg = (
#     212                         f"{shorthand} encoding field is specified without a type; "
#
# ValueError: Unable to determine data type for the field "duration_min"; verify that the field name is not misspelled. If you are referencing a field from a transform, also confirm that the data type is specified correctly.
# alt.Chart(...)
